# %%
import pandas as pd
import json, os

import tensorflow as tf
import numpy as np
import csv
from transformers import AutoTokenizer, TFAutoModel, TFAutoModelForSequenceClassification #, BertModel, BertTokenizer, TFBertForSequenceClassification
import matplotlib.pyplot as plt
import random
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K
from collections import OrderedDict
import time
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, \
roc_auc_score, confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
import random
import io

from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, SimpleRNN
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Masking
from tensorflow.keras.layers import Embedding, MaxPool1D
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras import optimizers
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Bidirectional, BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.initializers import glorot_uniform, RandomUniform, lecun_uniform, Constant
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from collections import OrderedDict
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, GlobalMaxPool1D
import tensorflow.keras.backend as K

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense, GlobalMaxPool1D

from sklearn.metrics import classification_report
from keras_preprocessing.text import tokenizer_from_json

import nltk
from nltk.tokenize import word_tokenize

import seaborn as sns

# %%
seed = 123
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

# %%
embeddings = ["w2v", "ft", "bert", "codebert"]
embedding = embeddings[3]

# %% [markdown]
# Choose a project among Chrome and Linux or the full dataset

# %%
#data = pd.read_csv(os.path.join('..','data', 'full_data_reduced.csv'))
#data = pd.read_csv(os.path.join('..','data', 'chrome_data_reduced.csv'))
data = pd.read_csv(os.path.join('..','data', 'linux_data_reduced.csv'))

# %% [markdown]
# Shuffle the dataset before starting operating on it

# %%
data = data.sample(frac=1, random_state=seed).reset_index(drop=True)

# %%
print(data.head())
# Out:
#                                                 func  vul  length
# 0  static inline void __ap_schedule_poll_timer(vo...    0      30
# 1  static int sctp_autobind(struct sock *sk)\n{\n...    0      36
# 2  static ssize_t ucma_init_qp_attr(struct ucma_f...    0      88
# 3  static void __blk_mq_requeue_request(struct re...    0      24
# 4  static void vhost_net_flush(struct vhost_net *...    0      37

# %%
np.max(data["length"])
# Out:
# 237

# %%
word_counts = data["func"].apply(lambda x: len(x.split()))
max_length = word_counts.max()
print("Maximum number of words:", max_length)
# Out:
# Maximum number of words: 237

# %%
print(data["vul"].value_counts())

print((data["vul"].value_counts()[1]/data["vul"].value_counts()[0])*100, '%')
# Out:
# 0    43024
# 1     1439
# Name: vul, dtype: int64
# 3.344644849386389 %

# %% [markdown]
# PRE_PROCESSING

# %%
def padSequences(sequences, max_len):
    lines_pad = []
    for sequence in sequences:
        seq = sequence['input_ids'].numpy()[0]
        if len(seq) < max_len:
            for i in range(len(seq), max_len):
                seq = np.append(seq, 0)
        lines_pad.append(seq)
    return lines_pad

# %%
nltk.download('punkt')

tokenized_list = [word_tokenize(sentence) for sentence in data["func"].tolist()]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ilias\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Augmentation

# %% [markdown]
# BERT pre-trained embeddings

# %%
if embedding == "bert":
    model_variation = "bert-base-uncased" # "roberta-base"
    tokenizer = AutoTokenizer.from_pretrained(model_variation)
    bert = TFAutoModel.from_pretrained(model_variation)

# %%
if embedding == "bert":
    bert_embeddings = bert.get_input_embeddings()
    embedding_matrix = bert_embeddings.weights[0].numpy()
    num_words = len(embedding_matrix)
    print(num_words)
    dim = len(embedding_matrix[0])
    print(dim)

# %%
if embedding == "bert":
    sentences = data["func"].tolist()
    sequences = [tokenizer.encode(sente, truncation=True, add_special_tokens=False, return_tensors="tf").numpy() for sente in sentences] # Tokenize the complete sentences

# %%
if embedding == "bert":
    lines_pad = []
    for seq in sequences:
        lines_pad.append(seq[0])

    lines_pad = pad_sequences(lines_pad, padding = 'post', maxlen = 512)
    lines_pad

# %% [markdown]
# CodeBERT pre-trained CPP embeddings

# %%
if embedding == "codebert":
    model_variation = "microsoft/codebert-base-mlm" # "neulab/codebert-cpp"
    tokenizer = AutoTokenizer.from_pretrained(model_variation, do_lower_case=False) # , do_lower_case=True
    codebert = TFAutoModel.from_pretrained(model_variation) # , from_pt=True
# Out:
# Some layers from the model checkpoint at microsoft/codebert-base-mlm were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at microsoft/codebert-base-mlm.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.

# %%
if embedding == "codebert":
    codebert_embeddings = codebert.get_input_embeddings()
    embedding_matrix = codebert_embeddings.weights[0].numpy()
    num_words = len(embedding_matrix)
    print(num_words)
    dim = len(embedding_matrix[0])
    print(dim)
# Out:
# 50265
# 768

# %%
if embedding == "codebert":
    sentences = data["func"].tolist()
    sequences = [tokenizer(sente, return_tensors="tf", truncation=True, add_special_tokens=False) for sente in sentences]

# %%
def get_max_len(sequences):
    max_len = 0
    
    for seq in sequences:
        if len(seq['input_ids'].numpy()[0]) > max_len:
            max_len = len(seq['input_ids'].numpy()[0])
    
    return max_len

# %%
max_len = get_max_len(sequences)
print(max_len)
# Out:
# 512

# %%
if embedding == "codebert":
    lines_pad = padSequences(sequences, max_len)
    lines_pad = [arr.tolist() for arr in lines_pad]
    lines_pad = np.array(lines_pad)

# %% [markdown]
# CROSS-VALIDATION

# %%
# Evaluation functions
def recall_metric(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = (true_positives + K.epsilon()) / (possible_positives + K.epsilon())
        return recall

def precision_metric(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = (true_positives + K.epsilon()) / (predicted_positives + K.epsilon())
        return precision

def f1_metric(y_true, y_pred):

    prec = precision_metric(y_true, y_pred)
    rec = recall_metric(y_true, y_pred)
    f1 = 2*((prec*rec)/(prec+rec+K.epsilon()))
    return f1

def f2_metric(y_true, y_pred):

    prec = precision_metric(y_true, y_pred)
    rec = recall_metric(y_true, y_pred)
    f2 = 5*((prec*rec)/(4*prec+rec+K.epsilon()))
    return f2

# %%
# Deep Learning Models - Classifiers
def buildLstm(max_len, top_words, dim, seed, embedding_matrix):
    model=Sequential()
    #model.add(Embedding(input_dim=top_words+1, output_dim=dim, input_length=None, mask_zero=True))
    model.add(Embedding(input_dim=top_words, output_dim=dim, input_length=None, weights=[embedding_matrix], mask_zero=True, trainable=False))
    #model.add(SimpleRNN(300, dropout=0.3, stateful=False))
    model.add(LSTM(100, dropout=0.2, return_sequences=True, stateful=False))
    model.add(LSTM(50, dropout=0.1, stateful=False))
    #model.add(Bidirectional(LSTM(300, dropout=0.3, stateful=False)))
    #model.add(GRU(300, dropout=0.3, stateful=False))
    model.add(Activation('relu')) #dropout=0.2, recurrent_dropout=0.2, kernel_constraint=max_norm(3), bias_constraint=max_norm(3)
    model.add(BatchNormalization(momentum=0.0))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[f2_metric])  
    return model

def buildCnn(max_len, top_words, dim, seed, embedding_matrix):
    cnn_model = Sequential()
    cnn_model.add(Embedding(top_words, dim, input_length=None, weights=[embedding_matrix], mask_zero=True, trainable=False))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))
    '''cnn_model.add(MaxPooling1D(pool_size = 5))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))
    cnn_model.add(MaxPooling1D(pool_size = 5))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))'''
    cnn_model.add(GlobalMaxPool1D())
    #cnn_model.add(Dense(units = 128, activation = 'relu'))
    cnn_model.add(Dense(units = 1, activation = 'sigmoid'))
    cnn_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics=[f2_metric])
    return cnn_model

# %%
def runCrossVal(X, y, max_len, num_words, dim, seed, embedding_matrix, userModel):
    ############## cross validation
    scores=['accuracy', 'precision', 'recall', 'f1', 'roc_auc', 'f2']
    values = [np.array([]) for i in range(0, len(scores))]
    score_dict = OrderedDict(zip(scores, values))
    k=10
    f=0
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=seed)
    
    nb_epoch = 100
    BS = 64
    print("Training...")
    milli_sec1 = int(round(time.time() * 1000))
    
    for train_index, test_index in kfold.split(X, y):
        f = f + 1
        print('fold number= ',f)
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = y[train_index], y[test_index]
        
        
#         #sampling
#         X_res, Y_res = RandomOverSampler(random_state=seed, sampling_strategy=0.5).fit_resample(X_train, Y_train)
#         #X_res, Y_res = RandomUnderSampler(random_state=seed, sampling_strategy=0.5).fit_resample(X_train, Y_train)
    
#         #shuffle dataset
#         X_resampled=pd.DataFrame(X_res)
#         Y_resampled=pd.DataFrame(Y_res)
#         newTrain=X_resampled.assign(Label=Y_resampled.values)
#         newTrain = shuffle(newTrain,random_state=seed)
#         X_train=np.array(newTrain.iloc[:, 0:-1 ])
#         X_train=pd.DataFrame(X_train)
#         Y_train=np.array(newTrain.iloc[:, -1 ])
#         Y_train=pd.DataFrame(Y_train)
        
        if userModel == "cnn":
            myModel = buildCnn(max_len, num_words, dim, seed, embedding_matrix) 
        elif userModel == "lstm":
            myModel = buildLstm(max_len, num_words, dim, seed, embedding_matrix)

        print("model summary\m", myModel.summary())
        csv_logger = CSVLogger('log.csv', append=True, separator=',')
        es = EarlyStopping(monitor='val_f2_metric', mode='max', verbose=1, patience=10)
        mc = ModelCheckpoint('best_model.h5', monitor='val_f2_metric', mode='max', verbose=1, save_best_only=True)
        print(type(X_train))
        history = myModel.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs = nb_epoch, batch_size = BS, shuffle=True, verbose=1, callbacks=[csv_logger,es,mc])
        
        #load best model
        #model = load_model('best_model.h5')
        myModel.load_weights("best_model.h5")
        
        scores = myModel.evaluate(X_test, Y_test, verbose=0)
        #predictions = myModel.predict_classes(X_test, verbose=0)
        predScores = myModel.predict(X_test)
        predictions = (predScores > 0.5).astype("int32")
        
        accuracy=accuracy_score(Y_test, predictions)
        precision=precision_score(Y_test, predictions)
        recall=recall_score(Y_test, predictions)
        f1=f1_score(Y_test, predictions)
        roc_auc=roc_auc_score(Y_test, predictions)
        f2=5*precision*recall / (4*precision+recall)
        
        cm = confusion_matrix(Y_test, predictions, labels=[0, 1])
        #print(cm)
        sns.heatmap(cm, annot=True)
        tn, fp, fn, tp = cm.ravel()
        
        print("TP=",tp)
        print("TN=",tn)
        print("FP=",fp)
        print("FN=",fn)
        
        acc = ((tp+tn)/(tp+tn+fp+fn))
        
        print("Accuracy:%.2f%%"%(acc*100))
        print("Precision:%.2f%%"%(precision*100))
        print("Recall:%.2f%%"%(recall*100))
        print("F1 score:%.2f%%"%(f1*100))
        print("Roc_Auc score:%.2f%%"%(roc_auc*100))
        print("F2 score:%.2f%%"%(f2*100))
        print(classification_report(Y_test, predictions))
        
        del myModel
        
        score_dict['accuracy'] = np.append(score_dict['accuracy'], accuracy)
        score_dict['precision'] = np.append(score_dict['precision'], precision)
        score_dict['recall'] = np.append(score_dict['recall'], recall)
        score_dict['f1'] = np.append(score_dict['f1'], f1)
        score_dict['roc_auc'] = np.append(score_dict['roc_auc'], roc_auc)
        score_dict['f2'] = np.append(score_dict['f2'], f2)
        
    milli_sec2 = int(round(time.time() * 1000))
    print("Cross Validation is completed after", milli_sec2-milli_sec1)
    
    print("accuracy: %.2f%% (%.2f%%)" % (score_dict['accuracy'].mean()*100, score_dict['accuracy'].std()*100))
    print("precision: %.2f%% (%.2f%%)" % (score_dict['precision'].mean()*100, score_dict['precision'].std()*100))
    print("recall: %.2f%% (%.2f%%)" % (score_dict['recall'].mean()*100, score_dict['recall'].std()*100))
    print("f1: %.2f%% (%.2f%%)" % (score_dict['f1'].mean()*100, score_dict['f1'].std()*100))
    print("roc_auc: %.2f%% (%.2f%%)" % (score_dict['roc_auc'].mean()*100, score_dict['roc_auc'].std()*100))
    print("f2: %.2f%% (%.2f%%)" % (score_dict['f2'].mean()*100, score_dict['f2'].std()*100))

# %%
runCrossVal(lines_pad, data["vul"].values, max_len, num_words, dim, seed, embedding_matrix, "lstm")
# Out:
# Training...
# fold number=  1
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 768)         38603520
#
#  lstm (LSTM)                 (None, None, 100)         347600
#
#  lstm_1 (LSTM)               (None, 50)                30200
#
#  activation (Activation)     (None, 50)                0
#
#  batch_normalization (BatchN  (None, 50)               200
#  ormalization)
#
#  dense_6 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38,981,571
# Trainable params: 377,951
# Non-trainable params: 38,603,620
# _________________________________________________________________
# model summary\m None
# <class 'numpy.ndarray'>
# Epoch 1/100
# 626/626 [==============================] - ETA: 0s - loss: 0.2001 - f2_metric: 0.1625
# Epoch 1: val_f2_metric improved from -inf to 0.15720, saving model to best_model.h5
# 626/626 [==============================] - 41s 57ms/step - loss: 0.2001 - f2_metric: 0.1625 - val_loss: 0.1275 - val_f2_metric: 0.1572
# Epoch 2/100
# 626/626 [==============================] - ETA: 0s - loss: 0.1133 - f2_metric: 0.1816
# Epoch 2: val_f2_metric improved from 0.15720 to 0.41207, saving model to best_model.h5
# 626/626 [==============================] - 34s 54ms/step - loss: 0.1133 - f2_metric: 0.1816 - val_loss: 0.0694 - val_f2_metric: 0.4121
# Epoch 3/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0676 - f2_metric: 0.3463
# Epoch 3: val_f2_metric did not improve from 0.41207
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0676 - f2_metric: 0.3473 - val_loss: 0.1097 - val_f2_metric: 0.4069
# Epoch 4/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0653 - f2_metric: 0.3634
# Epoch 4: val_f2_metric did not improve from 0.41207
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0653 - f2_metric: 0.3645 - val_loss: 0.0662 - val_f2_metric: 0.1055
# Epoch 5/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0620 - f2_metric: 0.3555
# Epoch 5: val_f2_metric did not improve from 0.41207
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0620 - f2_metric: 0.3549 - val_loss: 0.0593 - val_f2_metric: 0.0857
# Epoch 6/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0619 - f2_metric: 0.3820
# Epoch 6: val_f2_metric improved from 0.41207 to 0.71628, saving model to best_model.h5
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0619 - f2_metric: 0.3820 - val_loss: 0.0604 - val_f2_metric: 0.7163
# Epoch 7/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0626 - f2_metric: 0.3584
# Epoch 7: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0626 - f2_metric: 0.3584 - val_loss: 0.1049 - val_f2_metric: 0.2781
# Epoch 8/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0760 - f2_metric: 0.3226
# Epoch 8: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0760 - f2_metric: 0.3237 - val_loss: 0.1189 - val_f2_metric: 0.1143
# Epoch 9/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0607 - f2_metric: 0.3540
# Epoch 9: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0607 - f2_metric: 0.3550 - val_loss: 0.0638 - val_f2_metric: 0.1198
# Epoch 10/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0648 - f2_metric: 0.3699
# Epoch 10: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0648 - f2_metric: 0.3693 - val_loss: 0.0718 - val_f2_metric: 0.1277
# Epoch 11/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0649 - f2_metric: 0.3952
# Epoch 11: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0649 - f2_metric: 0.3962 - val_loss: 0.0597 - val_f2_metric: 0.3635
# Epoch 12/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0616 - f2_metric: 0.3809
# Epoch 12: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0616 - f2_metric: 0.3809 - val_loss: 0.0676 - val_f2_metric: 0.7033
# Epoch 13/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0594 - f2_metric: 0.4254
# Epoch 13: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0594 - f2_metric: 0.4254 - val_loss: 0.0679 - val_f2_metric: 0.7128
# Epoch 14/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0581 - f2_metric: 0.4346
# Epoch 14: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0581 - f2_metric: 0.4355 - val_loss: 0.0628 - val_f2_metric: 0.6485
# Epoch 15/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0558 - f2_metric: 0.4437
# Epoch 15: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0558 - f2_metric: 0.4446 - val_loss: 0.0738 - val_f2_metric: 0.2144
# Epoch 16/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0539 - f2_metric: 0.4630
# Epoch 16: val_f2_metric did not improve from 0.71628
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0539 - f2_metric: 0.4639 - val_loss: 0.0687 - val_f2_metric: 0.3148
# Epoch 16: early stopping
# 139/139 [==============================] - 4s 15ms/step
# [[4196  107]
#  [  15  129]]
# Accuracy:97.26%
# Precision:54.66%
# Recall:89.58%
# F1 score:67.89%
# Roc_Auc score:93.55%
# F2 score:79.43%
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      4303
#            1       0.55      0.90      0.68       144
#
#     accuracy                           0.97      4447
#    macro avg       0.77      0.94      0.83      4447
# weighted avg       0.98      0.97      0.98      4447
#
# fold number=  2
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, None, 768)         38603520
#
#  lstm_2 (LSTM)               (None, None, 100)         347600
#
#  lstm_3 (LSTM)               (None, 50)                30200
#
#  activation_1 (Activation)   (None, 50)                0
#
#  batch_normalization_1 (Batc  (None, 50)               200
#  hNormalization)
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38,981,571
# Trainable params: 377,951
# Non-trainable params: 38,603,620
# _________________________________________________________________
# model summary\m None
# <class 'numpy.ndarray'>
# Epoch 1/100
# 626/626 [==============================] - ETA: 0s - loss: 0.1964 - f2_metric: 0.1519
# Epoch 1: val_f2_metric improved from -inf to 0.17143, saving model to best_model.h5
# 626/626 [==============================] - 40s 56ms/step - loss: 0.1964 - f2_metric: 0.1519 - val_loss: 0.1193 - val_f2_metric: 0.1714
# Epoch 2/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.1154 - f2_metric: 0.1644
# Epoch 2: val_f2_metric improved from 0.17143 to 0.38449, saving model to best_model.h5
# 626/626 [==============================] - 33s 53ms/step - loss: 0.1154 - f2_metric: 0.1641 - val_loss: 0.0715 - val_f2_metric: 0.3845
# Epoch 3/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0679 - f2_metric: 0.3672
# Epoch 3: val_f2_metric improved from 0.38449 to 0.62951, saving model to best_model.h5
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0679 - f2_metric: 0.3682 - val_loss: 0.0692 - val_f2_metric: 0.6295
# Epoch 4/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0644 - f2_metric: 0.4143
# Epoch 4: val_f2_metric did not improve from 0.62951
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0644 - f2_metric: 0.4137 - val_loss: 0.0659 - val_f2_metric: 0.5873
# Epoch 5/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0626 - f2_metric: 0.4067
# Epoch 5: val_f2_metric did not improve from 0.62951
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0627 - f2_metric: 0.4061 - val_loss: 0.0710 - val_f2_metric: 0.1571
# Epoch 6/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0614 - f2_metric: 0.4209
# Epoch 6: val_f2_metric improved from 0.62951 to 0.64294, saving model to best_model.h5
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0613 - f2_metric: 0.4218 - val_loss: 0.0798 - val_f2_metric: 0.6429
# Epoch 7/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0602 - f2_metric: 0.4341
# Epoch 7: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0602 - f2_metric: 0.4334 - val_loss: 0.0680 - val_f2_metric: 0.2358
# Epoch 8/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0578 - f2_metric: 0.4730
# Epoch 8: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0578 - f2_metric: 0.4723 - val_loss: 0.0706 - val_f2_metric: 0.1900
# Epoch 9/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0569 - f2_metric: 0.4394
# Epoch 9: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0569 - f2_metric: 0.4387 - val_loss: 0.0721 - val_f2_metric: 0.3462
# Epoch 10/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0539 - f2_metric: 0.5086
# Epoch 10: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0539 - f2_metric: 0.5086 - val_loss: 0.0877 - val_f2_metric: 0.6156
# Epoch 11/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0524 - f2_metric: 0.4861
# Epoch 11: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0524 - f2_metric: 0.4869 - val_loss: 0.0799 - val_f2_metric: 0.3207
# Epoch 12/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0504 - f2_metric: 0.5188
# Epoch 12: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0504 - f2_metric: 0.5196 - val_loss: 0.0804 - val_f2_metric: 0.3597
# Epoch 13/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0482 - f2_metric: 0.5243
# Epoch 13: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0482 - f2_metric: 0.5251 - val_loss: 0.0905 - val_f2_metric: 0.1939
# Epoch 14/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0473 - f2_metric: 0.5494
# Epoch 14: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0473 - f2_metric: 0.5486 - val_loss: 0.0900 - val_f2_metric: 0.5385
# Epoch 15/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0454 - f2_metric: 0.5620
# Epoch 15: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0454 - f2_metric: 0.5611 - val_loss: 0.0969 - val_f2_metric: 0.1693
# Epoch 16/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0438 - f2_metric: 0.5720
# Epoch 16: val_f2_metric did not improve from 0.64294
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0438 - f2_metric: 0.5711 - val_loss: 0.1030 - val_f2_metric: 0.1593
# Epoch 16: early stopping
# 139/139 [==============================] - 4s 15ms/step
# [[4165  138]
#  [  21  123]]
# Accuracy:96.42%
# Precision:47.13%
# Recall:85.42%
# F1 score:60.74%
# Roc_Auc score:91.10%
# F2 score:73.48%
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      4303
#            1       0.47      0.85      0.61       144
#
#     accuracy                           0.96      4447
#    macro avg       0.73      0.91      0.79      4447
# weighted avg       0.98      0.96      0.97      4447
#
# fold number=  3
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, None, 768)         38603520
#
#  lstm_4 (LSTM)               (None, None, 100)         347600
#
#  lstm_5 (LSTM)               (None, 50)                30200
#
#  activation_2 (Activation)   (None, 50)                0
#
#  batch_normalization_2 (Batc  (None, 50)               200
#  hNormalization)
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38,981,571
# Trainable params: 377,951
# Non-trainable params: 38,603,620
# _________________________________________________________________
# model summary\m None
# <class 'numpy.ndarray'>
# Epoch 1/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.1946 - f2_metric: 0.1701
# Epoch 1: val_f2_metric improved from -inf to 0.24576, saving model to best_model.h5
# 626/626 [==============================] - 40s 57ms/step - loss: 0.1945 - f2_metric: 0.1714 - val_loss: 0.1175 - val_f2_metric: 0.2458
# Epoch 2/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0922 - f2_metric: 0.2812
# Epoch 2: val_f2_metric did not improve from 0.24576
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0922 - f2_metric: 0.2823 - val_loss: 0.0653 - val_f2_metric: 0.1143
# Epoch 3/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0664 - f2_metric: 0.3925
# Epoch 3: val_f2_metric improved from 0.24576 to 0.68728, saving model to best_model.h5
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0664 - f2_metric: 0.3935 - val_loss: 0.0853 - val_f2_metric: 0.6873
# Epoch 4/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0644 - f2_metric: 0.3761
# Epoch 4: val_f2_metric did not improve from 0.68728
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0645 - f2_metric: 0.3755 - val_loss: 0.0894 - val_f2_metric: 0.1143
# Epoch 5/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0619 - f2_metric: 0.4293
# Epoch 5: val_f2_metric did not improve from 0.68728
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0619 - f2_metric: 0.4302 - val_loss: 0.0659 - val_f2_metric: 0.1143
# Epoch 6/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0609 - f2_metric: 0.4175
# Epoch 6: val_f2_metric improved from 0.68728 to 0.70249, saving model to best_model.h5
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0609 - f2_metric: 0.4184 - val_loss: 0.1148 - val_f2_metric: 0.7025
# Epoch 7/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0585 - f2_metric: 0.4547
# Epoch 7: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 33s 54ms/step - loss: 0.0585 - f2_metric: 0.4539 - val_loss: 0.0701 - val_f2_metric: 0.5893
# Epoch 8/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0560 - f2_metric: 0.4875
# Epoch 8: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0560 - f2_metric: 0.4867 - val_loss: 0.0689 - val_f2_metric: 0.5318
# Epoch 9/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0549 - f2_metric: 0.4973
# Epoch 9: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0550 - f2_metric: 0.4965 - val_loss: 0.0673 - val_f2_metric: 0.2425
# Epoch 10/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0526 - f2_metric: 0.5199
# Epoch 10: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0526 - f2_metric: 0.5207 - val_loss: 0.0736 - val_f2_metric: 0.1575
# Epoch 11/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0508 - f2_metric: 0.5386
# Epoch 11: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0508 - f2_metric: 0.5393 - val_loss: 0.1260 - val_f2_metric: 0.6722
# Epoch 12/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0501 - f2_metric: 0.5533
# Epoch 12: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0500 - f2_metric: 0.5540 - val_loss: 0.1071 - val_f2_metric: 0.6448
# Epoch 13/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0474 - f2_metric: 0.5699
# Epoch 13: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0474 - f2_metric: 0.5690 - val_loss: 0.0829 - val_f2_metric: 0.0909
# Epoch 14/100
# 626/626 [==============================] - ETA: 0s - loss: 0.0461 - f2_metric: 0.5777
# Epoch 14: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 33s 53ms/step - loss: 0.0461 - f2_metric: 0.5777 - val_loss: 0.1439 - val_f2_metric: 0.6762
# Epoch 15/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0444 - f2_metric: 0.5978
# Epoch 15: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0445 - f2_metric: 0.5969 - val_loss: 0.1039 - val_f2_metric: 0.1163
# Epoch 16/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.0436 - f2_metric: 0.6016
# Epoch 16: val_f2_metric did not improve from 0.70249
# 626/626 [==============================] - 34s 54ms/step - loss: 0.0437 - f2_metric: 0.6007 - val_loss: 0.0926 - val_f2_metric: 0.1530
# Epoch 16: early stopping
# 139/139 [==============================] - 4s 15ms/step
# [[4144  159]
#  [  12  132]]
# Accuracy:96.15%
# Precision:45.36%
# Recall:91.67%
# F1 score:60.69%
# Roc_Auc score:93.99%
# F2 score:76.12%
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      4303
#            1       0.45      0.92      0.61       144
#
#     accuracy                           0.96      4447
#    macro avg       0.73      0.94      0.79      4447
# weighted avg       0.98      0.96      0.97      4447
#
# fold number=  4
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, None, 768)         38603520
#
#  lstm_6 (LSTM)               (None, None, 100)         347600
#
#  lstm_7 (LSTM)               (None, 50)                30200
#
#  activation_3 (Activation)   (None, 50)                0
#
#  batch_normalization_3 (Batc  (None, 50)               200
#  hNormalization)
#
#  dense_9 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38,981,571
# Trainable params: 377,951
# Non-trainable params: 38,603,620
# _________________________________________________________________
# model summary\m None
# <class 'numpy.ndarray'>
# Epoch 1/100
# 625/626 [============================>.] - ETA: 0s - loss: 0.1973 - f2_metric: 0.1456
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 runCrossVal(lines_pad, data["vul"].values, max_len, num_words, dim, seed, embedding_matrix, "lstm")
#
# Cell In [25], line 46, in runCrossVal(X, y, max_len, num_words, dim, seed, embedding_matrix, userModel)
#      44 mc = ModelCheckpoint('best_model.h5', monitor='val_f2_metric', mode='max', verbose=1, save_best_only=True)
#      45 print(type(X_train))
# ---> 46 history = myModel.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs = nb_epoch, batch_size = BS, shuffle=True, verbose=1, callbacks=[csv_logger,es,mc])
#      48 #load best model
#      49 #model = load_model('best_model.h5')
#      50 myModel.load_weights("best_model.h5")
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1445, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1431 if getattr(self, '_eval_data_handler', None) is None:
#    1432   self._eval_data_handler = data_adapter.get_data_handler(
#    1433       x=val_x,
#    1434       y=val_y,
#    (...)
#    1443       model=self,
#    1444       steps_per_execution=self._steps_per_execution)
# -> 1445 val_logs = self.evaluate(
#    1446     x=val_x,
#    1447     y=val_y,
#    1448     sample_weight=val_sample_weight,
#    1449     batch_size=validation_batch_size or batch_size,
#    1450     steps=validation_steps,
#    1451     callbacks=callbacks,
#    1452     max_queue_size=max_queue_size,
#    1453     workers=workers,
#    1454     use_multiprocessing=use_multiprocessing,
#    1455     return_dict=True,
#    1456     _use_cached_eval_dataset=True)
#    1457 val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1458 epoch_logs.update(val_logs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1756, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754 with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755   callbacks.on_test_batch_begin(step)
# -> 1756   tmp_logs = self.test_function(iterator)
#    1757   if data_handler.should_sync:
#    1758     context.async_wait()
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:963, in Function._call(self, *args, **kwds)
#     960 try:
#     961   # This is the first call of __call__, so we have to initialize.
#     962   initializers = []
# --> 963   self._initialize(args, kwds, add_initializers_to=initializers)
#     964 finally:
#     965   # At this point we know that the initialization is complete (or less
#     966   # interestingly an exception was raised) so we no longer need a lock.
#     967   self._lock.release()
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:785, in Function._initialize(self, args, kwds, add_initializers_to)
#     782 self._lifted_initializer_graph = lifted_initializer_graph
#     783 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     784 self._concrete_stateful_fn = (
# --> 785     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     786         *args, **kwds))
#     788 def invalid_creator_scope(*unused_args, **unused_kwds):
#     789   """Disables variable creation."""
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2480, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2478   args, kwargs = None, None
#    2479 with self._lock:
# -> 2480   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2481 return graph_function
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1116, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1114 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1115 try:
# -> 1116   return autograph.converted_call(
#    1117       original_func,
#    1118       args,
#    1119       kwargs,
#    1120       options=autograph.ConversionOptions(
#    1121           recursive=True,
#    1122           optional_features=autograph_options,
#    1123           user_requested=True,
#    1124       ))
#    1125 except Exception as e:  # pylint:disable=broad-except
#    1126   if hasattr(e, "ag_error_metadata"):
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileyoo__f_z.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1546, in Model.make_test_function.<locals>.step_function(model, iterator)
#    1542   run_step = tf.function(
#    1543       run_step, jit_compile=True, reduce_retracing=True)
#    1545 data = next(iterator)
# -> 1546 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1547 outputs = reduce_per_replica(
#    1548     outputs, self.distribute_strategy, reduction='first')
#    1549 return outputs
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1535, in Model.make_test_function.<locals>.step_function.<locals>.run_step(data)
#    1534 def run_step(data):
# -> 1535   outputs = model.test_step(data)
#    1536   # Ensure counter is updated only if `test_step` succeeds.
#    1537   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1499, in Model.test_step(self, data)
#    1475 """The logic for one evaluation step.
#    1476
#    1477 This method can be overridden to support custom evaluation logic.
#    (...)
#    1495   values of the `Model`'s metrics are returned.
#    1496 """
#    1497 x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
# -> 1499 y_pred = self(x, training=False)
#    1500 # Updates stateful loss metrics.
#    1501 self.compute_loss(x, y, y_pred, sample_weight)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:490, in Model.__call__(self, *args, **kwargs)
#     486     super().__call__(inputs, *copied_args, **copied_kwargs)
#     488   layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 490 return super().__call__(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\sequential.py:374, in Sequential.call(self, inputs, training, mask)
#     372   if not self.built:
#     373     self._init_graph_network(self.inputs, self.outputs)
# --> 374   return super(Sequential, self).call(inputs, training=training, mask=mask)
#     376 outputs = inputs  # handle the corner case where self.layers is empty
#     377 for layer in self.layers:
#     378   # During each iteration, `inputs` are the inputs to `layer`, and `outputs`
#     379   # are the outputs of `layer` applied to `inputs`. At the end of each
#     380   # iteration `inputs` is set to `outputs` to prepare for the next layer.
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\functional.py:458, in Functional.call(self, inputs, training, mask)
#     439 @doc_controls.do_not_doc_inheritable
#     440 def call(self, inputs, training=None, mask=None):
#     441   """Calls the model on new inputs.
#     442
#     443   In this case `call` just reapplies
#    (...)
#     456       a list of tensors if there are more than one outputs.
#     457   """
# --> 458   return self._run_internal_graph(
#     459       inputs, training=training, mask=mask)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\functional.py:596, in Functional._run_internal_graph(self, inputs, training, mask)
#     593   continue  # Node is not computable, try skipping.
#     595 args, kwargs = node.map_arguments(tensor_dict)
# --> 596 outputs = node.layer(*args, **kwargs)
#     598 # Update tensor_dict.
#     599 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\layers\rnn\base_rnn.py:515, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     511 inputs, initial_state, constants = rnn_utils.standardize_args(
#     512     inputs, initial_state, constants, self._num_constants)
#     514 if initial_state is None and constants is None:
# --> 515   return super(RNN, self).__call__(inputs, **kwargs)
#     517 # If any of `initial_state` or `constants` are specified and are Keras
#     518 # tensors, then add them to the inputs and temporarily modify the
#     519 # input_spec to include them.
#     521 additional_inputs = []
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\layers\rnn\lstm.py:673, in LSTM.call(self, inputs, mask, training, initial_state)
#     669         last_output, outputs, new_h, new_c, runtime = standard_lstm(
#     670             **normal_lstm_kwargs)
#     671     else:
#     672       (last_output, outputs, new_h, new_c,
# --> 673        runtime) = lstm_with_backend_selection(**normal_lstm_kwargs)
#     675   states = [new_h, new_c]
#     677 if self.stateful:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\layers\rnn\lstm.py:1183, in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1177   defun_gpu_lstm = gru_lstm_utils.generate_defun_backend(
#    1178       api_name, gru_lstm_utils.GPU_DEVICE_NAME, gpu_lstm_with_fallback,
#    1179       supportive_attribute)
#    1181   # Call the normal LSTM impl and register the cuDNN impl function. The
#    1182   # grappler will kick in during session execution to optimize the graph.
# -> 1183   last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(**params)
#    1184   gru_lstm_utils.function_register(defun_gpu_lstm, **params)
#    1186 return last_output, outputs, new_h, new_c, runtime
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2452, in Function.__call__(self, *args, **kwargs)
#    2449 """Calls a graph function specialized to the inputs."""
#    2450 with self._lock:
#    2451   (graph_function,
# -> 2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\layers\rnn\lstm.py:891, in standard_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#     888   h = o * tf.tanh(c)
#     889   return h, [h, c]
# --> 891 last_output, outputs, new_states = backend.rnn(
#     892     step,
#     893     inputs, [init_h, init_c],
#     894     constants=None,
#     895     unroll=False,
#     896     time_major=time_major,
#     897     mask=mask,
#     898     go_backwards=go_backwards,
#     899     input_length=(sequence_lengths
#     900                   if sequence_lengths is not None else timesteps),
#     901     zero_output_for_mask=zero_output_for_mask,
#     902     return_all_outputs=return_sequences)
#     903 return (last_output, outputs, new_states[0], new_states[1],
#     904         gru_lstm_utils.runtime(gru_lstm_utils.RUNTIME_CPU))
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\keras\backend.py:4739, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#    4732   output_ta_t = tuple(
#    4733       ta.write(ta_index_to_write, out)
#    4734       for ta, out in zip(output_ta_t, flat_new_output))
#    4736   return (time + 1, output_ta_t,
#    4737           tuple(flat_new_output)) + tuple(new_states)
# -> 4739 final_outputs = tf.compat.v1.while_loop(
#    4740     body=_step,
#    4741     loop_vars=(time, output_ta, flat_zero_output) + states,
#    4742     **while_loop_kwargs)
#    4743 # Skip final_outputs[2] which is the output for final timestep.
#    4744 new_states = final_outputs[3:]
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2705, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2702 executing_eagerly = context.executing_eagerly()
#    2703 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#    2704     not executing_eagerly):
# -> 2705   return while_v2.while_loop(
#    2706       cond,
#    2707       body,
#    2708       loop_vars,
#    2709       shape_invariants=shape_invariants,
#    2710       parallel_iterations=parallel_iterations,
#    2711       maximum_iterations=maximum_iterations,
#    2712       name=name,
#    2713       return_same_structure=return_same_structure,
#    2714       back_prop=back_prop)
#    2716 with ops.name_scope(name, "while", loop_vars):
#    2717   if not loop_vars:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\while_v2.py:213, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     209   # TODO(srbs): Update lowering code to create _Enter nodes with
#     210   # is_constant=True for inputs that are directly passed to outputs.
#     211   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 213 body_graph = func_graph_module.func_graph_from_py_func(
#     214     body_name,
#     215     wrapped_body,
#     216     [],  # We provide signature instead of args.
#     217     {},
#     218     signature=func_graph_signature,
#     219     func_graph=util.WhileBodyFuncGraph(
#     220         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     221     add_control_dependencies=add_control_dependencies,
#     222     acd_record_initial_resource_uses=stateful_parallelism)
#     223 # Add external captures of body to the list of loop vars.
#     224 # Note that external tensors will be treated as loop invariants, i.e.,
#     225 # the value of that tensor in each iteration is the same as it was at the
#     226 # beginning of the loop execution.
#     227 deferred_external_captures = nest.flatten(
#     228     [c() for c in body_graph.deferred_external_captures],
#     229     expand_composites=True)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1145, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1141   func_outputs = python_func(*func_args, **func_kwargs)
#    1143   # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144   # TensorArrays and `None`s.
# -> 1145   func_outputs = nest.map_structure(
#    1146       convert, func_outputs, expand_composites=True)
#    1148   check_func_mutation(func_args_before, func_kwargs_before, func_args,
#    1149                       func_kwargs, original_func)
#    1150 finally:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\nest.py:916, in map_structure(func, *structure, **kwargs)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\nest.py:916, in <listcomp>(.0)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1104, in func_graph_from_py_func.<locals>.convert(x)
#    1097     raise TypeError(
#    1098         "To be compatible with tf.function, Python functions "
#    1099         "must return zero or more Tensors or ExtensionTypes or None "
#    1100         f"values; in compilation of {str(python_func)}, found return "
#    1101         f"value of type {type(x).__name__}, which is not a Tensor or "
#    1102         "ExtensionType.")
#    1103 if add_control_dependencies:
# -> 1104   x = deps_ctx.mark_as_return(x)
#    1105 return x
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\auto_control_deps.py:249, in AutomaticControlDependencies.mark_as_return(self, tensor)
#     244   return tensor_array_ops.build_ta_with_new_flow(tensor, flow)
#     245 # We want to make the return values depend on the stateful operations, but
#     246 # we don't want to introduce a cycle, so we make the return value the result
#     247 # of a new identity operation that the stateful operations definitely don't
#     248 # depend on.
# --> 249 tensor = array_ops.identity(tensor)
#     250 self._returned_tensors.add(tensor)
#     251 return tensor
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:295, in identity(input, name)
#     291 if context.executing_eagerly() and not hasattr(input, "graph"):
#     292   # Make sure we get an input with handle data attached from resource
#     293   # variables. Variables have correct handle data when graph building.
#     294   input = ops.convert_to_tensor(input)
# --> 295 ret = gen_array_ops.identity(input, name=name)
#     296 # Propagate handle data for happier shape inference for resource variables.
#     297 if hasattr(input, "_handle_data"):
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4076, in identity(input, name)
#    4074     pass  # Add nodes to the TensorFlow graph.
#    4075 # Add nodes to the TensorFlow graph.
# -> 4076 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    4077       "Identity", input=input, name=name)
#    4078 _result = _outputs[:]
#    4079 if _execute.must_record_gradient():
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\func_graph.py:694, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     692   inp = self.capture(inp)
#     693   captured_inputs.append(inp)
# --> 694 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     695     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     696     compute_device)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py:3754, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3751 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3752 # Session.run call cannot occur between creating and mutating the op.
#    3753 with self._mutation_lock():
# -> 3754   ret = Operation(
#    3755       node_def,
#    3756       self,
#    3757       inputs=inputs,
#    3758       output_types=dtypes,
#    3759       control_inputs=control_inputs,
#    3760       input_types=input_types,
#    3761       original_op=self._default_original_op,
#    3762       op_def=op_def)
#    3763   self._create_op_helper(ret, compute_device=compute_device)
#    3764 return ret
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py:2129, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2127   if op_def is None:
#    2128     op_def = self._graph._get_op_def(node_def.op)
# -> 2129   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2130                             control_input_ops, op_def)
#    2131   name = compat.as_str(node_def.name)
#    2133 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py:1960, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1956   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1957                                          serialized)
#    1959 try:
# -> 1960   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1961 except errors.InvalidArgumentError as e:
#    1962   # Convert to ValueError for backwards compatibility.
#    1963   raise ValueError(e.message)
#
# KeyboardInterrupt:
